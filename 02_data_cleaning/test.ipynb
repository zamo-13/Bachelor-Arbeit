# %%
import polars as pr

# %%
path = r"C:\BA_Data\tiktok_de_2025_harmonized.parquet"
path2 = r"C:\BA_Data\tiktok_de_2025.parquet"

# %%
last_5 = (
    pr.scan_parquet(path)
    .tail(5)
    .collect()
)

last_6 = (
    pr.scan_parquet(path2)
    .tail(5)
    .collect()
)

# %%
last_5
# Out:
# shape: (5, 12)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ uuid      ┆ content_t ┆ automated ┆ automated ┆ … ┆ category_ ┆ applicati ┆ category_ ┆ applicat │
# │ ---       ┆ ype       ┆ _detectio ┆ _decision ┆   ┆ raw       ┆ on_date_r ┆ harmonize ┆ ion_date │
# │ str       ┆ ---       ┆ n         ┆ ---       ┆   ┆ ---       ┆ aw        ┆ d         ┆ _harmoni │
# │           ┆ str       ┆ ---       ┆ str       ┆   ┆ str       ┆ ---       ┆ ---       ┆ zed      │
# │           ┆           ┆ str       ┆           ┆   ┆           ┆ date      ┆ str       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ date     │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 4792b3a4- ┆ ["CONTENT ┆ Yes       ┆ AUTOMATED ┆ … ┆ STATEMENT ┆ 2025-10-0 ┆ PROTECTIO ┆ 2025-10- │
# ...

# %%
last_6
# Out:
# shape: (5, 10)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ uuid      ┆ category  ┆ content_t ┆ automated ┆ … ┆ applicati ┆ platform_ ┆ decision_ ┆ api_vers │
# │ ---       ┆ ---       ┆ ype       ┆ _detectio ┆   ┆ on_date   ┆ name      ┆ visibilit ┆ ion      │
# │ str       ┆ str       ┆ ---       ┆ n         ┆   ┆ ---       ┆ ---       ┆ y         ┆ ---      │
# │           ┆           ┆ str       ┆ ---       ┆   ┆ datetime[ ┆ str       ┆ ---       ┆ str      │
# │           ┆           ┆           ┆ str       ┆   ┆ ms]       ┆           ┆ str       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 85c0103d- ┆ STATEMENT ┆ ["CONTENT ┆ Yes       ┆ … ┆ 2025-12-1 ┆ TikTok    ┆ ["DECISIO ┆ v2       │
# │ 5f58-43d6 ┆ _CATEGORY ┆ _TYPE_TEX ┆           ┆   ┆ 2         ┆           ┆ N_VISIBIL ┆          │
# ...
